# %%
import os
import tensorflow as tf

BATCH_SIZE = 32
EPOCHS = 10
IMG_SIZE = (224, 224)
SEED = 42

def extract_family_genus_and_species_from_path(path):
    # TensorFlow operation to extract the folder name from the full path
    parts = tf.strings.split(path, os.sep)
    folder_name = parts[
        -2
    ]  # Assumes the structure '/.../family_genus_species/image.jpg'

    # Split the folder name assuming the format "family_genus_species"
    family_genus_species = tf.strings.split(folder_name, "_")
    family = family_genus_species[-3]
    genus = family_genus_species[-2]
    species = family_genus_species[-2] + " " + family_genus_species[-1]

    return family, genus, species

def process_path(path, family_labels, genus_labels, species_labels):
    # Load the raw data from the file as a string
    img = tf.io.read_file(path)

    # Decode the image
    img = tf.image.decode_jpeg(img, channels=3)

    # Resize the image to the desired size
    img = tf.image.resize(img, [224, 224])

    # Get the family, genus, and species labels
    family, genus, species = extract_family_genus_and_species_from_path(path)

    # Convert family, genus, and species to indices
    family_label = tf.argmax(tf.equal(family_labels, family))
    genus_label = tf.argmax(tf.equal(genus_labels, genus))
    species_label = tf.argmax(tf.equal(species_labels, species))

    # Convert to one-hot encoded format
    family_label = tf.one_hot(family_label, len(family_labels))
    genus_label = tf.one_hot(genus_label, len(genus_labels))
    species_label = tf.one_hot(species_label, len(species_labels))

    # Return the image and a dictionary of labels with matching keys
    return img, {
        "family": family_label,
        "genus": genus_label,
        "species": species_label
    }

def build_dataset(directory, batch_size=32):
    # Get list of all files and extract labels
    file_paths = []
    family_labels = set()
    genus_labels = set()
    species_labels = set()

    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith((".jpg", ".jpeg", ".png")):
                file_path = os.path.join(root, file)
                file_paths.append(file_path)

                # Extract family, genus, and species
                folder_name = os.path.basename(os.path.dirname(file_path))
                family, genus, species = folder_name.split("_")

                species = genus + " " + species

                # Collect unique family, genus, and species names
                family_labels.add(family)
                genus_labels.add(genus)
                species_labels.add(species)

    # Convert sets to sorted lists to keep label indices consistent
    family_labels = sorted(list(family_labels))
    genus_labels = sorted(list(genus_labels))
    species_labels = sorted(list(species_labels))

    # Create a TensorFlow dataset from the file paths
    path_ds = tf.data.Dataset.from_tensor_slices(file_paths)

    # Convert family, genus, and species labels to TensorFlow tensors
    family_labels = tf.constant(family_labels)
    genus_labels = tf.constant(genus_labels)
    species_labels = tf.constant(species_labels)

    # Map the processing function to the dataset
    image_label_ds = path_ds.map(
        lambda x: process_path(x, family_labels, genus_labels, species_labels),
        num_parallel_calls=tf.data.AUTOTUNE,
    )

    # Shuffle, batch, and prefetch the dataset
    image_label_ds = image_label_ds.shuffle(buffer_size=len(file_paths))
    image_label_ds = image_label_ds.batch(batch_size)
    image_label_ds = image_label_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

    return (
        image_label_ds,
        family_labels.numpy().tolist(),
        genus_labels.numpy().tolist(),
        species_labels.numpy().tolist(),
    )

# Usage
train_ds, family_labels, genus_labels, species_labels = build_dataset(
    "/Users/leonardo/Documents/Projects/cryptovision/data/processed/train"
)
val_ds, family_labels, genus_labels, species_labels = build_dataset(
    "/Users/leonardo/Documents/Projects/cryptovision/data/processed/valid"
)
test_ds, family_labels, genus_labels, species_labels = build_dataset(
    "/Users/leonardo/Documents/Projects/cryptovision/data/processed/test"
)
# Out:
# 2024-10-21 11:37:20.788299: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2024-10-21 11:37:20.788322: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2024-10-21 11:37:20.788327: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# 2024-10-21 11:37:20.788338: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-21 11:37:20.788347: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
valid_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Data Augmentation Function
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.2),
        tf.keras.layers.RandomTranslation(0.1, 0.1),
        tf.keras.layers.RandomContrast(0.2),
        tf.keras.layers.RandomBrightness(0.2),
    ]
)

# %%
import matplotlib.pyplot as plt

for image, _ in train_ds.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')
# Out:
# 2024-10-21 11:37:33.588713: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Image Preprocessing
preprocess_input = tf.keras.applications.resnet_v2.preprocess_input

base_model = tf.keras.applications.ResNet50V2(
    input_shape=IMG_SIZE + (3,),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False

# Define the inputs and apply augmentation
inputs = tf.keras.Input(shape=IMG_SIZE + (3,))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.2)(x)

# Define family output
family_output = tf.keras.layers.Dense(len(family_labels), activation='softmax', name='family')(x)

# Concatenate the family output with the base model output
family_features = tf.keras.layers.Concatenate()([x, family_output])

# Define genus output, using family features as additional input
genus_hidden = tf.keras.layers.Dense(256, activation='relu')(family_features)
genus_output = tf.keras.layers.Dense(len(genus_labels), activation='softmax', name='genus')(genus_hidden)

# Concatenate the family and genus outputs with the base model output
genus_features = tf.keras.layers.Concatenate()([x, family_output, genus_output])

# Define species output, using both family and genus features as additional input
species_hidden = tf.keras.layers.Dense(256, activation='relu')(genus_features)
species_output = tf.keras.layers.Dense(len(species_labels), activation='softmax', name='species')(species_hidden)

# Create the hierarchical model
model = tf.keras.Model(inputs, [family_output, genus_output, species_output])


base_learning_rate = 0.0001
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
    loss={
        'family': 'categorical_crossentropy',
        'genus': 'categorical_crossentropy',
        'species': 'categorical_crossentropy'
    },
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 224, 224,  │          0 │ input_layer_2[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ true_divide         │ (None, 224, 224,  │          0 │ sequential[0][0]  │
# │ (TrueDivide)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract (Subtract) │ (None, 224, 224,  │          0 │ true_divide[0][0] │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50v2          │ (None, 7, 7,      │ 23,564,800 │ subtract[0][0]    │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50v2[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ family (Dense)      │ (None, 18)        │     36,882 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 2066)      │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ family[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    529,152 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ genus (Dense)       │ (None, 45)        │     11,565 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 2111)      │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ family[0][0],     │
# │                     │                   │            │ genus[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    540,672 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ species (Dense)     │ (None, 57)        │     14,649 │ dense_1[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,697,720 (94.21 MB)
#  Trainable params: 1,132,920 (4.32 MB)
#  Non-trainable params: 23,564,800 (89.89 MB)

# %%
base_learning_rate = 0.0001
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
    loss={
        'family': 'categorical_crossentropy',
        'genus': 'categorical_crossentropy',
        'species': 'categorical_crossentropy'
    },
    metrics={
        'family': ['accuracy'],
        'genus': ['accuracy'],
        'species': ['accuracy']
    }
)

# %%
history = model.fit(
    train_ds,
    epochs=10,
    validation_data=val_ds
)
# Out:
# Epoch 1/10
# 2024-10-21 11:38:18.032062: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 51s 244ms/step - family_accuracy: 0.1181 - family_loss: 3.2164 - genus_accuracy: 0.1705 - genus_loss: 3.5185 - loss: 10.4943 - species_accuracy: 0.1572 - species_loss: 3.7595 - val_family_accuracy: 0.3729 - val_family_loss: 1.9333 - val_genus_accuracy: 0.5504 - val_genus_loss: 1.9124 - val_loss: 6.0179 - val_species_accuracy: 0.5083 - val_species_loss: 2.1715
# Epoch 2/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 41s 226ms/step - family_accuracy: 0.3767 - family_loss: 1.9468 - genus_accuracy: 0.5392 - genus_loss: 1.8890 - loss: 5.9808 - species_accuracy: 0.4874 - species_loss: 2.1451 - val_family_accuracy: 0.5435 - val_family_loss: 1.4490 - val_genus_accuracy: 0.6775 - val_genus_loss: 1.3075 - val_loss: 4.2031 - val_species_accuracy: 0.6526 - val_species_loss: 1.4524
# Epoch 3/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 42s 230ms/step - family_accuracy: 0.5220 - family_loss: 1.5415 - genus_accuracy: 0.6453 - genus_loss: 1.3511 - loss: 4.3880 - species_accuracy: 0.6142 - species_loss: 1.4955 - val_family_accuracy: 0.6278 - val_family_loss: 1.1855 - val_genus_accuracy: 0.7217 - val_genus_loss: 1.0434 - val_loss: 3.3808 - val_species_accuracy: 0.7120 - val_species_loss: 1.1321
# Epoch 4/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 41s 226ms/step - family_accuracy: 0.6034 - family_loss: 1.2863 - genus_accuracy: 0.7099 - genus_loss: 1.0791 - loss: 3.5589 - species_accuracy: 0.6829 - species_loss: 1.1941 - val_family_accuracy: 0.6830 - val_family_loss: 1.0225 - val_genus_accuracy: 0.7721 - val_genus_loss: 0.8756 - val_loss: 2.8765 - val_species_accuracy: 0.7541 - val_species_loss: 0.9600
# Epoch 5/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 41s 225ms/step - family_accuracy: 0.6398 - family_loss: 1.1455 - genus_accuracy: 0.7370 - genus_loss: 0.9425 - loss: 3.1132 - species_accuracy: 0.7259 - species_loss: 1.0261 - val_family_accuracy: 0.7175 - val_family_loss: 0.9395 - val_genus_accuracy: 0.7859 - val_genus_loss: 0.8108 - val_loss: 2.6197 - val_species_accuracy: 0.7790 - val_species_loss: 0.8727
# Epoch 6/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 41s 229ms/step - family_accuracy: 0.6740 - family_loss: 1.0355 - genus_accuracy: 0.7637 - genus_loss: 0.8482 - loss: 2.8012 - species_accuracy: 0.7464 - species_loss: 0.9177 - val_family_accuracy: 0.7403 - val_family_loss: 0.8520 - val_genus_accuracy: 0.8059 - val_genus_loss: 0.7597 - val_loss: 2.4089 - val_species_accuracy: 0.7852 - val_species_loss: 0.7806
# Epoch 7/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 41s 227ms/step - family_accuracy: 0.6937 - family_loss: 0.9723 - genus_accuracy: 0.7671 - genus_loss: 0.7880 - loss: 2.6095 - species_accuracy: 0.7660 - species_loss: 0.8494 - val_family_accuracy: 0.7617 - val_family_loss: 0.7920 - val_genus_accuracy: 0.8122 - val_genus_loss: 0.7003 - val_loss: 2.2454 - val_species_accuracy: 0.8046 - val_species_loss: 0.7393
# Epoch 8/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 41s 224ms/step - family_accuracy: 0.7147 - family_loss: 0.9097 - genus_accuracy: 0.7857 - genus_loss: 0.7363 - loss: 2.4308 - species_accuracy: 0.7866 - species_loss: 0.7851 - val_family_accuracy: 0.7749 - val_family_loss: 0.7648 - val_genus_accuracy: 0.8273 - val_genus_loss: 0.6610 - val_loss: 2.1436 - val_species_accuracy: 0.8087 - val_species_loss: 0.7116
# Epoch 9/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 40s 223ms/step - family_accuracy: 0.7356 - family_loss: 0.8468 - genus_accuracy: 0.8073 - genus_loss: 0.6753 - loss: 2.2348 - species_accuracy: 0.8039 - species_loss: 0.7131 - val_family_accuracy: 0.7811 - val_family_loss: 0.7263 - val_genus_accuracy: 0.8211 - val_genus_loss: 0.6515 - val_loss: 2.0611 - val_species_accuracy: 0.8142 - val_species_loss: 0.6857
# Epoch 10/10
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 42s 232ms/step - family_accuracy: 0.7434 - family_loss: 0.8206 - genus_accuracy: 0.8154 - genus_loss: 0.6402 - loss: 2.1241 - species_accuracy: 0.8123 - species_loss: 0.6648 - val_family_accuracy: 0.7894 - val_family_loss: 0.6846 - val_genus_accuracy: 0.8377 - val_genus_loss: 0.6058 - val_loss: 1.9566 - val_species_accuracy: 0.8267 - val_species_loss: 0.6412

# %%
results = model.evaluate(test_ds)
#print(results)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - family_accuracy: 0.7845 - family_loss: 0.7137 - genus_accuracy: 0.8527 - genus_loss: 0.5479 - loss: 1.8372 - species_accuracy: 0.8461 - species_loss: 0.5757

# %%
results = model.evaluate(test_ds)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - family_accuracy: 0.9236 - family_loss: 0.2614 - genus_accuracy: 0.9180 - genus_loss: 0.3105 - loss: 0.9243 - species_accuracy: 0.9049 - species_loss: 0.3521

# %%
print(f"Family Acc: {results[4]:.3f}")
print(f"Genus Acc: {results[5]:.3f}")
print(f"Species Acc: {results[6]:.3f}")
# Out:
# Family Acc: 0.917
# Genus Acc: 0.909
# Species Acc: 0.901

# %%
base_model.trainable = True

# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 140

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  190

# %%
model.compile(
  optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
  loss="categorical_crossentropy", 
  metrics={
        'family': ['accuracy'],
        'genus': ['accuracy'],
        'species': ['accuracy']
    }
)

# %%
fine_tune_epochs = 10
total_epochs =  10 + fine_tune_epochs

history_fine = model.fit(
    train_ds,
    epochs=total_epochs,
    initial_epoch=len(history.epoch),
    validation_data=val_ds,
)
# Out:
# Epoch 11/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 337ms/step - family_accuracy: 0.7089 - family_loss: 1.0031 - genus_accuracy: 0.7626 - genus_loss: 0.9326 - loss: 2.9277 - species_accuracy: 0.7577 - species_loss: 0.9925 - val_family_accuracy: 0.8149 - val_family_loss: 0.6030 - val_genus_accuracy: 0.8494 - val_genus_loss: 0.5830 - val_loss: 1.7890 - val_species_accuracy: 0.8336 - val_species_loss: 0.6222
# Epoch 12/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 57s 314ms/step - family_accuracy: 0.7649 - family_loss: 0.7738 - genus_accuracy: 0.8226 - genus_loss: 0.6734 - loss: 2.1529 - species_accuracy: 0.8119 - species_loss: 0.7070 - val_family_accuracy: 0.8494 - val_family_loss: 0.5118 - val_genus_accuracy: 0.8584 - val_genus_loss: 0.5225 - val_loss: 1.5916 - val_species_accuracy: 0.8474 - val_species_loss: 0.5623
# Epoch 13/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 57s 313ms/step - family_accuracy: 0.8123 - family_loss: 0.6248 - genus_accuracy: 0.8617 - genus_loss: 0.5170 - loss: 1.6946 - species_accuracy: 0.8515 - species_loss: 0.5530 - val_family_accuracy: 0.8736 - val_family_loss: 0.4487 - val_genus_accuracy: 0.8653 - val_genus_loss: 0.4789 - val_loss: 1.4327 - val_species_accuracy: 0.8550 - val_species_loss: 0.5245
# Epoch 14/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 57s 317ms/step - family_accuracy: 0.8399 - family_loss: 0.5261 - genus_accuracy: 0.8824 - genus_loss: 0.4426 - loss: 1.4273 - species_accuracy: 0.8779 - species_loss: 0.4591 - val_family_accuracy: 0.8840 - val_family_loss: 0.3989 - val_genus_accuracy: 0.8750 - val_genus_loss: 0.4449 - val_loss: 1.3137 - val_species_accuracy: 0.8619 - val_species_loss: 0.4855
# Epoch 15/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 56s 309ms/step - family_accuracy: 0.8527 - family_loss: 0.4981 - genus_accuracy: 0.8817 - genus_loss: 0.4290 - loss: 1.3680 - species_accuracy: 0.8789 - species_loss: 0.4410 - val_family_accuracy: 0.8923 - val_family_loss: 0.3547 - val_genus_accuracy: 0.8847 - val_genus_loss: 0.4105 - val_loss: 1.2293 - val_species_accuracy: 0.8715 - val_species_loss: 0.4480
# Epoch 16/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 58s 320ms/step - family_accuracy: 0.8628 - family_loss: 0.4226 - genus_accuracy: 0.8967 - genus_loss: 0.3532 - loss: 1.1516 - species_accuracy: 0.8916 - species_loss: 0.3761 - val_family_accuracy: 0.9047 - val_family_loss: 0.3331 - val_genus_accuracy: 0.8826 - val_genus_loss: 0.4054 - val_loss: 1.1718 - val_species_accuracy: 0.8736 - val_species_loss: 0.4410
# Epoch 17/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 59s 324ms/step - family_accuracy: 0.8867 - family_loss: 0.3839 - genus_accuracy: 0.9044 - genus_loss: 0.3347 - loss: 1.0850 - species_accuracy: 0.8922 - species_loss: 0.3668 - val_family_accuracy: 0.9088 - val_family_loss: 0.3087 - val_genus_accuracy: 0.8895 - val_genus_loss: 0.3809 - val_loss: 1.1181 - val_species_accuracy: 0.8798 - val_species_loss: 0.4152
# Epoch 18/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 56s 311ms/step - family_accuracy: 0.9005 - family_loss: 0.3488 - genus_accuracy: 0.9163 - genus_loss: 0.3063 - loss: 0.9825 - species_accuracy: 0.9135 - species_loss: 0.3275 - val_family_accuracy: 0.9123 - val_family_loss: 0.2860 - val_genus_accuracy: 0.8923 - val_genus_loss: 0.3676 - val_loss: 1.0652 - val_species_accuracy: 0.8826 - val_species_loss: 0.4049
# Epoch 19/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 56s 308ms/step - family_accuracy: 0.9104 - family_loss: 0.3055 - genus_accuracy: 0.9256 - genus_loss: 0.2684 - loss: 0.8738 - species_accuracy: 0.9133 - species_loss: 0.3000 - val_family_accuracy: 0.9206 - val_family_loss: 0.2735 - val_genus_accuracy: 0.8971 - val_genus_loss: 0.3628 - val_loss: 1.0178 - val_species_accuracy: 0.8833 - val_species_loss: 0.3910
# Epoch 20/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 56s 308ms/step - family_accuracy: 0.9170 - family_loss: 0.2738 - genus_accuracy: 0.9320 - genus_loss: 0.2489 - loss: 0.7890 - species_accuracy: 0.9222 - species_loss: 0.2665 - val_family_accuracy: 0.9206 - val_family_loss: 0.2583 - val_genus_accuracy: 0.8950 - val_genus_loss: 0.3472 - val_loss: 0.9917 - val_species_accuracy: 0.8881 - val_species_loss: 0.3751

# %%
model.save('CV_RES50V2_HMOP_102124_1200.keras')

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

def predict_image(image_path, model, family_labels, genus_labels, species_labels, top_k=3):
    """
    Predict the top-k family, genus, and species from an image using a trained model,
    and display the image with predictions.

    Args:
    - image_path (str): Path to the image file.
    - model (tf.keras.Model): The trained model.
    - family_labels (list): List of family labels.
    - genus_labels (list): List of genus labels.
    - species_labels (list): List of species labels.
    - top_k (int): Number of top predictions to return.

    Returns:
    - top_k_family: List of tuples (family, confidence) for top k family predictions.
    - top_k_genus: List of tuples (genus, confidence) for top k genus predictions.
    - top_k_species: List of tuples (species, confidence) for top k species predictions.
    """

    # Load and preprocess the image
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [224, 224])
    img = tf.expand_dims(img, 0)  # Add batch dimension

    # Predict family, genus, and species
    family_pred, genus_preds, species_preds = model.predict(img)
    
    # Get top-k predictions for family
    top_k_family_indices = np.argsort(family_pred[0])[-top_k:][::-1]
    top_k_family = [(family_labels[i], family_pred[0][i]) for i in top_k_family_indices]

    # Get top-k predictions for genus
    top_k_genus_indices = np.argsort(genus_preds[0])[-top_k:][::-1]
    top_k_genus = [(genus_labels[i], genus_preds[0][i]) for i in top_k_genus_indices]

    # Get top-k predictions for species
    top_k_species_indices = np.argsort(species_preds[0])[-top_k:][::-1]
    top_k_species = [(species_labels[i], species_preds[0][i]) for i in top_k_species_indices]

    # Display the image
    plt.figure(figsize=(6, 6))
    plt.imshow(tf.image.resize(img[0], [224, 224]) / 255.0)
    plt.axis('off')
    plt.title("Input Image")
    plt.show()

    # Print top-k predictions for each level
    print("Top 3 Family Predictions:")
    for family, confidence in top_k_family:
        print(f"{family}: {confidence:.4f}")

    print("\nTop 3 Genus Predictions:")
    for genus, confidence in top_k_genus:
        print(f"{genus}: {confidence:.4f}")

    print("\nTop 3 Species Predictions:")
    for species, confidence in top_k_species:
        print(f"{species}: {confidence:.4f}")

    return top_k_family, top_k_genus, top_k_species

# %%
image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Istigobius_decoratus/21689_web_Istigobius_decoratus_441.jpeg'
image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Istigobius_decoratus/86970_web_Istigobius_decoratus_496.jpeg'
image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Istigobius_decoratus/fish_photo_7204.jpeg'
image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Trimma_macrophthalmus/65426378_fish_photo_10654.jpeg'
image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Trimma_macrophthalmus/21775_web_Trimma_macrophthalmus_32.jpeg'
image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Eviota_melasma/66367_web_Eviota_melasma_6.jpeg'
#image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Gobiodon_histrio/99036_web_Gobiodon_histrio_42.jpeg'
#image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Paragobiodon_modestus/web_Paragobiodon_modestus_13.jpeg'

#image_path = '/Volumes/T7_shield/CryptoVision/Data/new_dataset/Site V/JMC_9199.JPG'

#image_path = '/Users/leonardo/Documents/Projects/cryptovision/data/processed/test/Gobiidae_Eviota_melasma/fish_photo_7799.jpeg'

top_k_family, top_k_genus, top_k_species = predict_image(
    image_path, model, family_labels, genus_labels, species_labels, top_k=3
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Top 3 Family Predictions:
# b'Gobiidae': 0.9936
# b'Tripterygiidae': 0.0039
# b'Blenniidae': 0.0010
#
# Top 3 Genus Predictions:
# b'Eviota': 0.9727
# b'Aioliops': 0.0170
# b'Ecsenius': 0.0030
#
# Top 3 Species Predictions:
# b'Eviota atriventris': 0.3643
# b'Eviota melasma': 0.2776
# b'Eviota albolineata': 0.1615
